# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter('ignore')

# %%
df = pd.read_csv(r"C:\Users\L.RAMYA\Downloads\diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Data cleaning

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
columns_to_check = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 
                    'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
df[df['Glucose'] == 0][['Glucose']]
# Out:
#      Glucose
# 75         0
# 182        0
# 342        0
# 349        0
# 502        0

# %%
df[df['BloodPressure'] == 0][['BloodPressure']]
# Out:
#      BloodPressure
# 7                0
# 15               0
# 49               0
# 60               0
# 78               0
# 81               0
# 172              0
# 193              0
# 222              0
# 261              0
# 266              0
# 269              0
# 300              0
# 332              0
# 336              0
# 347              0
# 357              0
# 426              0
# 430              0
# 435              0
# 453              0
# 468              0
# 484              0
# 494              0
# 522              0
# 533              0
# 535              0
# 589              0
# 601              0
# 604              0
# 619              0
# 643              0
# 697              0
# 703              0
# 706              0

# %%
df[df['SkinThickness'] == 0][['SkinThickness']]
# Out:
#      SkinThickness
# 2                0
# 5                0
# 7                0
# 9                0
# 10               0
# ..             ...
# 757              0
# 758              0
# 759              0
# 762              0
# 766              0
#
# [227 rows x 1 columns]

# %%
df[df['Insulin'] == 0][['Insulin']]
# Out:
#      Insulin
# 0          0
# 1          0
# 2          0
# 5          0
# 7          0
# ..       ...
# 761        0
# 762        0
# 764        0
# 766        0
# 767        0
#
# [374 rows x 1 columns]

# %%
df[df['BMI'] == 0][['BMI']]
# Out:
#      BMI
# 9    0.0
# 49   0.0
# 60   0.0
# 81   0.0
# 145  0.0
# 371  0.0
# 426  0.0
# 494  0.0
# 522  0.0
# 684  0.0
# 706  0.0

# %%
df[df['DiabetesPedigreeFunction'] == 0][['DiabetesPedigreeFunction']]
# Out:
# Empty DataFrame
# Columns: [DiabetesPedigreeFunction]
# Index: []

# %%
df[df['Age'] == 0][['Age']]
# Out:
# Empty DataFrame
# Columns: [Age]
# Index: []

# %%
df.drop(df[df['SkinThickness'] == 0].index, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.drop(df[df['Glucose'] == 0].index, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.drop(df[df['BloodPressure'] == 0].index, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.drop(df[df['SkinThickness'] == 0].index, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.drop(df[df['Insulin'] == 0].index, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 755            1      128             88             39      110  36.5
# 760            2       88             58             26       16  28.4
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
df.drop(df[df['BMI'] == 0].index, inplace=True)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 755            1      128             88             39      110  36.5
# 760            2       88             58             26       16  28.4
# 763           10      101             76             48      180  32.9
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1       89             66             23       94  28.1
# 1              0      137             40             35      168  43.1
# 2              3       78             50             32       88  31.0
# 3              2      197             70             45      543  30.5
# 4              1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 387            0      181             88             44      510  43.3
# 388            1      128             88             39      110  36.5
# 389            2       88             58             26       16  28.4
# 390           10      101             76             48      180  32.9
# 391            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.167   21        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               392 non-null    int64
#  1   Glucose                   392 non-null    int64
#  2   BloodPressure             392 non-null    int64
#  3   SkinThickness             392 non-null    int64
#  4   Insulin                   392 non-null    int64
#  5   BMI                       392 non-null    float64
#  6   DiabetesPedigreeFunction  392 non-null    float64
#  7   Age                       392 non-null    int64
#  8   Outcome                   392 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 27.7 KB

# %%
df.shape
# Out:
# (392, 9)

# %%
continous =['Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
count =['Pregnancies']
categorical =['outcome']

# %%
df[continous].describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  392.000000     392.000000     392.000000  392.000000  392.000000
# mean   122.627551      70.663265      29.145408  156.056122   33.086224
# std     30.860781      12.496092      10.516424  118.841690    7.027659
# min     56.000000      24.000000       7.000000   14.000000   18.200000
# 25%     99.000000      62.000000      21.000000   76.750000   28.400000
# 50%    119.000000      70.000000      29.000000  125.500000   33.200000
# 75%    143.000000      78.000000      37.000000  190.000000   37.100000
# max    198.000000     110.000000      63.000000  846.000000   67.100000
#
#        DiabetesPedigreeFunction         Age
# count                392.000000  392.000000
# mean                   0.523046   30.864796
# std                    0.345488   10.200777
# min                    0.085000   21.000000
# 25%                    0.269750   23.000000
# 50%                    0.449500   27.000000
# ...

# %%
df[continous].skew()
# Out:
# Glucose                     0.517850
# BloodPressure              -0.087516
# SkinThickness               0.209311
# Insulin                     2.165116
# BMI                         0.663485
# DiabetesPedigreeFunction    1.959101
# Age                         1.403607
# dtype: float64

# %% [markdown]
# - **Right-Skewed**
# - Insulin--->2.163100
# - DiabetesPedigreeFunction --->1.599700
# - Age--->1.252900
# - Remaining all are normally distributed
# -  if minimum value is zero we no need to apply the log

# %%
import math 
df['Insulin']=df['Insulin']**(1/3)
df['Insulin'].skew()
# Out:
# 0.6487089089457907

# %%
df['DiabetesPedigreeFunction']=df['DiabetesPedigreeFunction']**(1/2)
df['DiabetesPedigreeFunction'].skew()
# Out:
# 0.8051896086768858

# %%
df['Age'] = df['Age']**(1/4)
df['Age'].skew()
# Out:
# 0.9758968409654334

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   Insulin   BMI  \
# 0              1       89             66             23  4.546836  28.1
# 1              0      137             40             35  5.517848  43.1
# 2              3       78             50             32  4.447960  31.0
# 3              2      197             70             45  8.158305  30.5
# 4              1      189             60             23  9.457800  30.1
# ..           ...      ...            ...            ...       ...   ...
# 387            0      181             88             44  7.989570  43.3
# 388            1      128             88             39  4.791420  36.5
# 389            2       88             58             26  2.519842  28.4
# 390           10      101             76             48  5.646216  32.9
# 391            5      121             72             23  4.820285  26.2
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                    0.408656  2.140695        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               392 non-null    int64
#  1   Glucose                   392 non-null    int64
#  2   BloodPressure             392 non-null    int64
#  3   SkinThickness             392 non-null    int64
#  4   Insulin                   392 non-null    float64
#  5   BMI                       392 non-null    float64
#  6   DiabetesPedigreeFunction  392 non-null    float64
#  7   Age                       392 non-null    float64
#  8   Outcome                   392 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 27.7 KB

# %%
df[continous].describe()
# Out:
#           Glucose  BloodPressure  SkinThickness     Insulin         BMI  \
# count  392.000000     392.000000     392.000000  392.000000  392.000000
# mean   122.627551      70.663265      29.145408    5.108894   33.086224
# std     30.860781      12.496092      10.516424    1.189396    7.027659
# min     56.000000      24.000000       7.000000    2.410142   18.200000
# 25%     99.000000      62.000000      21.000000    4.249697   28.400000
# 50%    119.000000      70.000000      29.000000    5.006649   33.200000
# 75%    143.000000      78.000000      37.000000    5.748897   37.100000
# max    198.000000     110.000000      63.000000    9.457800   67.100000
#
#        DiabetesPedigreeFunction         Age
# count                392.000000  392.000000
# mean                   0.689905    2.336451
# std                    0.217250    0.175983
# min                    0.291548    2.140695
# 25%                    0.519374    2.189939
# 50%                    0.670445    2.279507
# ...

# %%
df[continous].skew()
# Out:
# Glucose                     0.517850
# BloodPressure              -0.087516
# SkinThickness               0.209311
# Insulin                     0.648709
# BMI                         0.663485
# DiabetesPedigreeFunction    0.805190
# Age                         0.975897
# dtype: float64

# %%
sns.histplot(df['Glucose'],kde=True)
plt.show()

# %%
sns.histplot(df['SkinThickness'],kde=True)
plt.show()

# %%
sns.histplot(df['BloodPressure'],kde=True)
plt.show()

# %%
sns.histplot(df['Insulin'],kde=True)
plt.show()

# %%
sns.histplot(df['BMI'],kde=True)
plt.show()

# %%
sns.histplot(df['DiabetesPedigreeFunction'],kde=True)
plt.show()

# %%
sns.histplot(df['Age'],kde=True)
plt.show()

# %%
sns.boxplot(df['SkinThickness'])
plt.show()

# %%
sns.boxplot(df['Age'])
plt.show()

# %%
sns.boxplot(df['DiabetesPedigreeFunction'])
plt.show()

# %%
sns.boxplot(df['Insulin'])
plt.show()

# %%
sns.boxplot(df['BMI'])
plt.show()

# %%
sns.boxplot(df['BloodPressure'])
plt.show()

# %%
sns.boxplot(df['Glucose'])
plt.show()

# %%
sns.heatmap(df[continous].corr(),annot=True)
plt.show()

# %%
X = df.drop('Outcome',axis=1)
y = df['Outcome']

# %%
Train =[]
CV =[]
for i in range(0,10):
    from sklearn.model_selection import train_test_split
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=i)
    
    from sklearn.linear_model import LinearRegression
    model =LinearRegression()
    model.fit(X_train,y_train)
    
    ypred_train = model.predict(X_train)

    from sklearn.metrics import r2_score
    Train.append(r2_score(y_train,ypred_train))
    
    from sklearn.model_selection import cross_val_score
    CV.append(cross_val_score(model,X_train,y_train,cv=5).mean())

em = pd.DataFrame({'Train':Train,'CV':CV})
gm = em[(abs(em['Train']-em['CV'])<=0.05)]
rs = gm[gm['CV']==gm['CV'].max()].index.tolist()[0]
print('best random state number:',rs)
# Out:
# best random state number: 3

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
df.to_excel('cleandiabetic.xlsx',index=False)
